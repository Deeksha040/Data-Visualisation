# %%
import numpy as np
import pandas as pd
df=pd.read_csv("south_pen-India_rainfall_act_dep_1901_2016.csv")
df.sort_values(["Actual Rainfall: JUN"],ascending=
              False)['YEAR'].head(1)
# Out:
# 90    1991
# Name: YEAR, dtype: int64

# %%
df["s1"]=df["Actual Rainfall: JUN"]+df["Actual Rainfall: JUL"]+df["Actual Rainfall: AUG"]+df["Actual Rainfall: SEPT"]
print(df.sort_values("s1",ascending=True)["YEAR"].head(5))
# Out:
# 17     1918
# 101    2002
# 51     1952
# 86     1987
# 4      1905
# Name: YEAR, dtype: int64

# %%
df1=pd.read_csv("central-India_rainfall_act_dep_1901_2016.csv")
df1["c1"]=df1["Actual Rainfall: JUN"]+df1["Actual Rainfall: JUL"]+df1["Actual Rainfall: AUG"]+df1["Actual Rainfall: SEPT"]+df1["Actual Rainfall: JUN-SEPT"]
print(df1.sort_values("c1",ascending=True)["YEAR"].head(5))
# Out:
# 17    1918
# 86    1987
# 73    1974
# 71    1972
# 19    1920
# Name: YEAR, dtype: int64

# %%
df2=pd.read_csv("ne-India_rainfall_act_dep_1901_2016.csv")
df2["ne2"]=df2["Actual Rainfall: JUN"]+df2["Actual Rainfall: JUL"]+df2["Actual Rainfall: AUG"]+df2["Actual Rainfall: SEPT"]+df2["Actual Rainfall: JUN-SEPT"]
print(df2.sort_values("ne2",ascending=False)["YEAR"].head(5))
# Out:
# 86    1987
# 17    1918
# 21    1922
# 87    1988
# 20    1921
# Name: YEAR, dtype: int64

# %%
df3=pd.read_csv("nw-India_rainfall_act_dep_1901_2016.csv")
df3["ns3"]=df3["Actual Rainfall: JUN"]+df3["Actual Rainfall: JUL"]+df3["Actual Rainfall: AUG"]+df3["Actual Rainfall: SEPT"]+df3["Actual Rainfall: JUN-SEPT"]
print(df3.sort_values("ns3",ascending=False)["YEAR"].head(5))
# Out:
# 16    1917
# 74    1975
# 15    1916
# 8     1909
# 41    1942
# Name: YEAR, dtype: int64

# %%
df["south_pen-India_rainfall_act_dep_1901_2016"]=df["Actual Rainfall: JUN"]+df["Actual Rainfall: JUL"]+df["Actual Rainfall: AUG"]+df["Actual Rainfall: SEPT"]
print(df[df["south_pen-India_rainfall_act_dep_1901_2016"]==df["south_pen-India_rainfall_act_dep_1901_2016"].max()]["YEAR"].head(1))
# Out:
# 58    1959
# Name: YEAR, dtype: int64

# %%
df1["central-India_rainfall_act_dep_1901_2016"]=df1["Actual Rainfall: JUN"]+df1["Actual Rainfall: JUL"]+df1["Actual Rainfall: AUG"]+df1["Actual Rainfall: SEPT"]
print(df1[df1["central-India_rainfall_act_dep_1901_2016"]==df1["central-India_rainfall_act_dep_1901_2016"].max()]["YEAR"].head(1))
# Out:
# 93    1994
# Name: YEAR, dtype: int64

# %%
df2["ne-India_rainfall_act_dep_1901_2016"]=df2["Actual Rainfall: JUN"]+df2["Actual Rainfall: JUL"]+df2["Actual Rainfall: AUG"]+df2["Actual Rainfall: SEPT"]
print(df2[df2["ne-India_rainfall_act_dep_1901_2016"]==df2["ne-India_rainfall_act_dep_1901_2016"].max()]["YEAR"].head(1))
# Out:
# 86    1987
# Name: YEAR, dtype: int64

# %%
df3["nw-India_rainfall_act_dep_1901_2016"]=df3["Actual Rainfall: JUN"]+df3["Actual Rainfall: JUL"]+df3["Actual Rainfall: AUG"]+df3["Actual Rainfall: SEPT"]
print(df3[df3["nw-India_rainfall_act_dep_1901_2016"]==df3["nw-India_rainfall_act_dep_1901_2016"].max()]["YEAR"].head(1))
# Out:
# 16    1917
# Name: YEAR, dtype: int64

# %%
df["s1"]=df["Departure Percentage: JUN"]
df.sort_values("s1",ascending=False)
# Out:
#      YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 90   1991                 278.0                 239.3                 167.2
# 106  2007                 242.5                 205.6                 223.1
# 58   1959                 236.7                 342.2                 201.3
# 95   1996                 233.8                 198.8                 239.0
# 77   1978                 208.7                 264.2                 224.1
# 55   1956                 210.8                 277.1                 158.8
# 28   1929                 207.1                 161.7                 119.6
# 112  2013                 206.1                 274.6                 164.9
# 16   1917                 206.4                 157.1                 198.1
# 74   1975                 204.4                 245.5                 225.9
# 60   1961                 213.2                 353.5                 207.5
# ...
